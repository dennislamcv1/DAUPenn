# %% [markdown]
# ## Module 5
#
# In this assignment, you are going to work on Histograms and Scatterplots.
#
# We have preprocessed the data as "df" for you.
#
# Follow the instructions and finish the rest part.

# %%
# %%capture
###########################################################
### EXECUTE THIS CELL BEFORE YOU TO TEST YOUR SOLUTIONS ###
###########################################################
import imp, os, sys
sol = imp.load_compiled("solutions", "./solutions.py")
sol.get_solutions("imdb.xlsx")
from nose.tools import assert_equal
from pandas.util.testing import assert_frame_equal, assert_series_equal

# %%
# Loading the data
import pandas as pd
import numpy as np

xls = pd.ExcelFile('imdb.xlsx')
df = xls.parse('imdb')
df_directors = xls.parse('directors')
df_countries = xls.parse('countries')

df = pd.merge(left=df, right=df_countries, 
              how='inner', left_on='country_id', 
              right_on='id')

df = pd.merge(left=df, right=df_directors, 
              how='inner', left_on='director_id', 
              right_on='id')

print("Finished.")
# Out:
# Finished.

# %%
df.head()
# Out:
#                 movie_title  director_id  country_id content_rating  \
# 0  The Shawshank Redemption           34           1              R
# 1  The Shawshank Redemption           34           1              R
# 2            The Green Mile           34           1              R
# 3            The Green Mile           34           1              R
# 4             The Godfather           33           1              R
#
#    title_year  imdb_score      gross  duration  id_x country  id_y  \
# 0        1994         9.3   28341469       142     1     USA    34
# 1        1994         9.3   28341469       142     1     USA    34
# 2        1999         8.5  136801374       189     1     USA    34
# 3        1999         8.5  136801374       189     1     USA    34
# 4        1972         9.2  134821952       175     1     USA    33
#
#           director_name
# 0        Frank Darabont
# 1        Frank Darabont
# 2        Frank Darabont
# 3        Frank Darabont
# 4  Francis Ford Coppola

# %%
df_after_2000 = df[df["title_year"] >= 2000]

# %%
df_after_2000.head()
# Out:
#         movie_title  director_id  country_id content_rating  title_year  \
# 13  The Dark Knight           16           1          PG-13        2008
# 14  The Dark Knight           16           1          PG-13        2008
# 15  The Dark Knight           16           1          PG-13        2008
# 16  The Dark Knight           16           1          PG-13        2008
# 17  The Dark Knight           16           1          PG-13        2008
#
#     imdb_score      gross  duration  id_x country  id_y      director_name
# 13         9.0  533316061       152     1     USA    16  Christopher Nolan
# 14         9.0  533316061       152     1     USA    16  Christopher Nolan
# 15         9.0  533316061       152     1     USA    16  Christopher Nolan
# 16         9.0  533316061       152     1     USA    16  Christopher Nolan
# 17         9.0  533316061       152     1     USA    16  Christopher Nolan

# %%
df_after_2000["grossnorm"] = (df_after_2000["gross"])/1000000
# Out:
# <ipython-input-5-d485f2b98350>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_after_2000["grossnorm"] = (df_after_2000["gross"])/1000000

# %%
df_after_2000.head()
# Out:
#         movie_title  director_id  country_id content_rating  title_year  \
# 13  The Dark Knight           16           1          PG-13        2008
# 14  The Dark Knight           16           1          PG-13        2008
# 15  The Dark Knight           16           1          PG-13        2008
# 16  The Dark Knight           16           1          PG-13        2008
# 17  The Dark Knight           16           1          PG-13        2008
#
#     imdb_score      gross  duration  id_x country  id_y      director_name  \
# 13         9.0  533316061       152     1     USA    16  Christopher Nolan
# 14         9.0  533316061       152     1     USA    16  Christopher Nolan
# 15         9.0  533316061       152     1     USA    16  Christopher Nolan
# 16         9.0  533316061       152     1     USA    16  Christopher Nolan
# 17         9.0  533316061       152     1     USA    16  Christopher Nolan
#
#      grossnorm
# 13  533.316061
# 14  533.316061
# 15  533.316061
# 16  533.316061
# 17  533.316061

# %%
df_before_2000 = df[df["title_year"] < 2000]

# %%
df_before_2000.head()
# Out:
#                 movie_title  director_id  country_id content_rating  \
# 0  The Shawshank Redemption           34           1              R
# 1  The Shawshank Redemption           34           1              R
# 2            The Green Mile           34           1              R
# 3            The Green Mile           34           1              R
# 4             The Godfather           33           1              R
#
#    title_year  imdb_score      gross  duration  id_x country  id_y  \
# 0        1994         9.3   28341469       142     1     USA    34
# 1        1994         9.3   28341469       142     1     USA    34
# 2        1999         8.5  136801374       189     1     USA    34
# 3        1999         8.5  136801374       189     1     USA    34
# 4        1972         9.2  134821952       175     1     USA    33
#
#           director_name
# 0        Frank Darabont
# 1        Frank Darabont
# 2        Frank Darabont
# 3        Frank Darabont
# 4  Francis Ford Coppola

# %%
df_before_2000["grossnorm"] = (df_before_2000["gross"])/1000000
# Out:
# <ipython-input-9-4cc642f0552a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_before_2000["grossnorm"] = (df_before_2000["gross"])/1000000

# %%
df_before_2000.head()
# Out:
#                 movie_title  director_id  country_id content_rating  \
# 0  The Shawshank Redemption           34           1              R
# 1  The Shawshank Redemption           34           1              R
# 2            The Green Mile           34           1              R
# 3            The Green Mile           34           1              R
# 4             The Godfather           33           1              R
#
#    title_year  imdb_score      gross  duration  id_x country  id_y  \
# 0        1994         9.3   28341469       142     1     USA    34
# 1        1994         9.3   28341469       142     1     USA    34
# 2        1999         8.5  136801374       189     1     USA    34
# 3        1999         8.5  136801374       189     1     USA    34
# 4        1972         9.2  134821952       175     1     USA    33
#
#           director_name   grossnorm
# 0        Frank Darabont   28.341469
# 1        Frank Darabont   28.341469
# 2        Frank Darabont  136.801374
# 3        Frank Darabont  136.801374
# 4  Francis Ford Coppola  134.821952

# %%
"""Q1: 
Is how much a movie makes indicative of how good it is?
Make a simple scatter plot comparing gross to imdb_score for movies after 2000 and before 2000.
It may be useful to scale the x axis demarking gross. (Hint: Divide the gross amount by 1,000,000.)
Remember to put a legend indicating which color corresponds to which years.
What is your verdict?

Save your plot in a variable called plt1, and your dataframes in variables called df_after_2000 and df_before_2000
"""

import matplotlib.pyplot as plt1

# your code here
plt1.figure(figsize=(8,6))
plt1.scatter(x=df_after_2000.grossnorm, y=df_after_2000.imdb_score, c='red')
plt1.scatter(x=df_before_2000.grossnorm, y=df_before_2000.imdb_score, c='blue')
plt1.legend(["After 2000","Before 2000"])
plt1.xlabel("Gross Normalized")
plt1.ylabel("IMDB score")

plt1.show()

# %%
assert_frame_equal(df_before_2000, sol.df_before_2000)
assert_frame_equal(df_after_2000, sol.df_after_2000)
np.testing.assert_array_equal(plt1, sol.plt1)

# %%
df_R = df[df["content_rating"] == "R"]

# %%
df_R
# Out:
#                   movie_title  director_id  country_id content_rating  \
# 0    The Shawshank Redemption           34           1              R
# 1    The Shawshank Redemption           34           1              R
# 2              The Green Mile           34           1              R
# 3              The Green Mile           34           1              R
# 4               The Godfather           33           1              R
# ..                        ...          ...         ...            ...
# 402           The Celebration          107          13              R
# 403        Dancer in the Dark           66          13              R
# 404           Pan's Labyrinth           42          17              R
# 406  The Secret in Their Eyes           61          16              R
# 407        Mad Max: Fury Road           39          19              R
#
#      title_year  imdb_score      gross  duration  id_x    country  id_y  \
# 0          1994         9.3   28341469       142     1        USA    34
# 1          1994         9.3   28341469       142     1        USA    34
# 2          1999         8.5  136801374       189     1        USA    34
# 3          1999         8.5  136801374       189     1        USA    34
# 4          1972         9.2  134821952       175     1        USA    33
# ..          ...         ...        ...       ...   ...        ...   ...
# 402        1998         8.1    1647780       105    13    Denmark   107
# 403        2000         8.0    4157491       140    13    Denmark    66
# 404        2006         8.2   37623143       112    17      Spain    42
# 406        2009         8.2   20167424       129    16  Argentina    61
# 407        2015         8.1  153629485       120    19  Australia    39
#
#             director_name
# 0          Frank Darabont
# 1          Frank Darabont
# 2          Frank Darabont
# 3          Frank Darabont
# 4    Francis Ford Coppola
# ..                    ...
# 402     Thomas Vinterberg
# 403        Lars von Trier
# 404    Guillermo del Toro
# 406  Juan Jose Campanella
# 407         George Miller
#
# [239 rows x 12 columns]

# %%
df_R.drop_duplicates(inplace=True)
# Out:
# <ipython-input-14-016e7909564e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_R.drop_duplicates(inplace=True)

# %%
df_R
# Out:
#                   movie_title  director_id  country_id content_rating  \
# 0    The Shawshank Redemption           34           1              R
# 2              The Green Mile           34           1              R
# 4               The Godfather           33           1              R
# 7      The Godfather: Part II           33           1              R
# 10             Apocalypse Now           33           1              R
# ..                        ...          ...         ...            ...
# 401           The Celebration          107          13              R
# 403        Dancer in the Dark           66          13              R
# 404           Pan's Labyrinth           42          17              R
# 406  The Secret in Their Eyes           61          16              R
# 407        Mad Max: Fury Road           39          19              R
#
#      title_year  imdb_score      gross  duration  id_x    country  id_y  \
# 0          1994         9.3   28341469       142     1        USA    34
# 2          1999         8.5  136801374       189     1        USA    34
# 4          1972         9.2  134821952       175     1        USA    33
# 7          1974         9.0   57300000       220     1        USA    33
# 10         1979         8.5   78800000       289     1        USA    33
# ..          ...         ...        ...       ...   ...        ...   ...
# 401        1998         8.1    1647780       105    13    Denmark   107
# 403        2000         8.0    4157491       140    13    Denmark    66
# 404        2006         8.2   37623143       112    17      Spain    42
# 406        2009         8.2   20167424       129    16  Argentina    61
# 407        2015         8.1  153629485       120    19  Australia    39
#
#             director_name
# 0          Frank Darabont
# 2          Frank Darabont
# 4    Francis Ford Coppola
# 7    Francis Ford Coppola
# 10   Francis Ford Coppola
# ..                    ...
# 401     Thomas Vinterberg
# 403        Lars von Trier
# 404    Guillermo del Toro
# 406  Juan Jose Campanella
# 407         George Miller
#
# [102 rows x 12 columns]

# %%
df_R = df_R["imdb_score"]

# %%
df_R
# Out:
# 0      9.3
# 2      8.5
# 4      9.2
# 7      9.0
# 10     8.5
#       ...
# 401    8.1
# 403    8.0
# 404    8.2
# 406    8.2
# 407    8.1
# Name: imdb_score, Length: 102, dtype: float64

# %%
df_PG13 = df[df["content_rating"] == "PG-13"]

# %%
df_PG13
# Out:
#          movie_title  director_id  country_id content_rating  title_year  \
# 13   The Dark Knight           16           1          PG-13        2008
# 14   The Dark Knight           16           1          PG-13        2008
# 15   The Dark Knight           16           1          PG-13        2008
# 16   The Dark Knight           16           1          PG-13        2008
# 17   The Dark Knight           16           1          PG-13        2008
# ..               ...          ...         ...            ...         ...
# 391       The Artist           75           7          PG-13        2011
# 392       Persepolis          114           7          PG-13        2007
# 393     A Separation            7          11          PG-13        2011
# 396  My Name Is Khan           63          10          PG-13        2010
# 405   The Sea Inside            2          17          PG-13        2004
#
#      imdb_score      gross  duration  id_x country  id_y        director_name
# 13          9.0  533316061       152     1     USA    16    Christopher Nolan
# 14          9.0  533316061       152     1     USA    16    Christopher Nolan
# 15          9.0  533316061       152     1     USA    16    Christopher Nolan
# 16          9.0  533316061       152     1     USA    16    Christopher Nolan
# 17          9.0  533316061       152     1     USA    16    Christopher Nolan
# ..          ...        ...       ...   ...     ...   ...                  ...
# 391         8.0   44667095       100     7  France    75  Michel Hazanavicius
# 392         8.0    4443403        89     7  France   114    Vincent Paronnaud
# 393         8.4    7098492       123    11    Iran     7       Asghar Farhadi
# 396         8.0    4018695       128    10   India    63          Karan Johar
# 405         8.1    2086345       125    17   Spain     2   Alejandro Amenabar
#
# [103 rows x 12 columns]

# %%
df_PG13.drop_duplicates(inplace=True)
# Out:
# <ipython-input-20-9d420a6886c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PG13.drop_duplicates(inplace=True)

# %%
df_PG13
# Out:
#                                            movie_title  director_id  \
# 13                                     The Dark Knight           16
# 20                                           Inception           16
# 27                                        Interstellar           16
# 41                                        The Prestige           16
# 48                               The Dark Knight Rises           16
# 55                                       Batman Begins           16
# 62       The Lord of the Rings: The Return of the King           83
# 65               The Lord of the Rings: The Two Towers           83
# 68   The Lord of the Rings: The Fellowship of the Ring           83
# 122                 Indiana Jones and the Last Crusade          103
# 127                                      Jurassic Park          103
# 142                                       Forrest Gump           92
# 211                                        The Martian           90
# 230                                         Inside Job           15
# 237                                Million Dollar Baby           17
# 258                         Captain America: Civil War            6
# 261                                            Warrior           37
# 266                                   A Beautiful Mind           95
# 269                                     Cinderella Man           95
# 290  Pirates of the Caribbean: The Curse of the Bla...           41
# 292                            Guardians of the Galaxy           49
# 294                                       The Avengers           60
# 296                                           Serenity           60
# 298                                    The Sixth Sense           69
# 299                               The Bourne Ultimatum           80
# 320                                           The Help          104
# 328                                              Sicko           73
# 333                    The Perks of Being a Wallflower          101
# 334                                           Big Fish          108
# 349                                  Princess Mononoke           46
# 376                                 The Imitation Game           77
# 381                                       Hotel Rwanda          105
# 390                  The Diving Bell and the Butterfly           62
# 391                                         The Artist           75
# 392                                         Persepolis          114
# 393                                       A Separation            7
# 396                                    My Name Is Khan           63
# 405                                     The Sea Inside            2
#
#      country_id content_rating  title_year  imdb_score      gross  duration  \
# 13            1          PG-13        2008         9.0  533316061       152
# 20            1          PG-13        2010         8.8  292568851       148
# 27            1          PG-13        2014         8.6  187991439       169
# 41            1          PG-13        2006         8.5   53082743       130
# 48            1          PG-13        2012         8.5  448130642       164
# 55            1          PG-13        2005         8.3  205343774       128
# 62            1          PG-13        2003         8.9  377019252       192
# 65            1          PG-13        2002         8.7  340478898       172
# 68            3          PG-13        2001         8.8  313837577       171
# 122           1          PG-13        1989         8.3  197171806       127
# 127           1          PG-13        1993         8.1  356784000       127
# 142           1          PG-13        1994         8.8  329691196       142
# 211           1          PG-13        2015         8.1  228430993       151
# 230           1          PG-13        2010         8.3    4311834       105
# 237           1          PG-13        2004         8.1  100422786       132
# 258           1          PG-13        2016         8.2  407197282       147
# 261           1          PG-13        2011         8.2   13651662       140
# 266           1          PG-13        2001         8.2  170708996       135
# 269           1          PG-13        2005         8.0   61644321       144
# 290           1          PG-13        2003         8.1  305388685       143
# 292           1          PG-13        2014         8.1  333130696       121
# 294           1          PG-13        2012         8.1  623279547       173
# 296           1          PG-13        2005         8.0   25335935       119
# 298           1          PG-13        1999         8.1  293501675       107
# 299           1          PG-13        2007         8.1  227137090       115
# 320           1          PG-13        2011         8.1  169705587       146
# 328           1          PG-13        2007         8.0   24530513       123
# 333           1          PG-13        2012         8.0   17738570       102
# 334           1          PG-13        2003         8.0   66257002       125
# 349           4          PG-13        1997         8.4    2298191       134
# 376           8          PG-13        2014         8.1   91121452       114
# 381           8          PG-13        2004         8.1   23472900       121
# 390           7          PG-13        2007         8.0    5990075       112
# 391           7          PG-13        2011         8.0   44667095       100
# 392           7          PG-13        2007         8.0    4443403        89
# 393          11          PG-13        2011         8.4    7098492       123
# 396          10          PG-13        2010         8.0    4018695       128
# 405          17          PG-13        2004         8.1    2086345       125
#
#      id_x      country  id_y        director_name
# 13      1          USA    16    Christopher Nolan
# 20      1          USA    16    Christopher Nolan
# 27      1          USA    16    Christopher Nolan
# 41      1          USA    16    Christopher Nolan
# 48      1          USA    16    Christopher Nolan
# 55      1          USA    16    Christopher Nolan
# 62      1          USA    83        Peter Jackson
# 65      1          USA    83        Peter Jackson
# 68      3  New Zealand    83        Peter Jackson
# 122     1          USA   103     Steven Spielberg
# 127     1          USA   103     Steven Spielberg
# 142     1          USA    92      Robert Zemeckis
# 211     1          USA    90         Ridley Scott
# 230     1          USA    15     Charles Ferguson
# 237     1          USA    17       Clint Eastwood
# 258     1          USA     6        Anthony Russo
# 261     1          USA    37       Gavin O'Connor
# 266     1          USA    95           Ron Howard
# 269     1          USA    95           Ron Howard
# 290     1          USA    41       Gore Verbinski
# 292     1          USA    49           James Gunn
# 294     1          USA    60          Joss Whedon
# 296     1          USA    60          Joss Whedon
# 298     1          USA    69   M. Night Shyamalan
# 299     1          USA    80      Paul Greengrass
# 320     1          USA   104          Tate Taylor
# 328     1          USA    73        Michael Moore
# 333     1          USA   101      Stephen Chbosky
# 334     1          USA   108           Tim Burton
# 349     4        Japan    46       Hayao Miyazaki
# 376     8           UK    77        Morten Tyldum
# 381     8           UK   105         Terry George
# 390     7       France    62      Julian Schnabel
# 391     7       France    75  Michel Hazanavicius
# 392     7       France   114    Vincent Paronnaud
# 393    11         Iran     7       Asghar Farhadi
# 396    10        India    63          Karan Johar
# 405    17        Spain     2   Alejandro Amenabar

# %%
df_PG13 = df_PG13["imdb_score"]

# %%
df_PG13
# Out:
# 13     9.0
# 20     8.8
# 27     8.6
# 41     8.5
# 48     8.5
# 55     8.3
# 62     8.9
# 65     8.7
# 68     8.8
# 122    8.3
# 127    8.1
# 142    8.8
# 211    8.1
# 230    8.3
# 237    8.1
# 258    8.2
# 261    8.2
# 266    8.2
# 269    8.0
# 290    8.1
# 292    8.1
# 294    8.1
# 296    8.0
# 298    8.1
# 299    8.1
# 320    8.1
# 328    8.0
# 333    8.0
# 334    8.0
# 349    8.4
# 376    8.1
# 381    8.1
# 390    8.0
# 391    8.0
# 392    8.0
# 393    8.4
# 396    8.0
# 405    8.1
# Name: imdb_score, dtype: float64

# %%
"""Q2: 
Using numpy and pyplot, make an overlapping histogram that shows the score distribution vs. count of R-Rated movies and PG-13 ones.
Describe your plot. 

Save your plot in a variable called plt2, and your dataframes in variables called df_R and df_PG13
"""

import matplotlib.pyplot as plt2

# your code here

plt2.figure(figsize=(8,6))
plt2.hist(x=df_R, bins=30)
plt2.hist(x=df_PG13, bins=30)
plt2.title("Score Distribution for R and PG13 movies")
plt2.legend(["R","PG-13"])

plt2.show()

# %%
assert_frame_equal(df_R, sol.df_R)
assert_frame_equal(df_PG13, sol.df_PG13)
np.testing.assert_array_equal(plt2, sol.plt2)
